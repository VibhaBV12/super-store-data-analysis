# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\vibha\Downloads\super store data set\SampleSuperstore.csv")

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.head(10)
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5  Standard Class   Consumer  United States      Los Angeles  California
# 6  Standard Class   Consumer  United States      Los Angeles  California
# 7  Standard Class   Consumer  United States      Los Angeles  California
# 8  Standard Class   Consumer  United States      Los Angeles  California
# 9  Standard Class   Consumer  United States      Los Angeles  California
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# ...

# %%
df.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
df.tail(20)
# Out:
#            Ship Mode      Segment        Country          City       State  \
# 9974  Standard Class  Home Office  United States   Los Angeles  California
# 9975  Standard Class  Home Office  United States   Los Angeles  California
# 9976  Standard Class  Home Office  United States   Los Angeles  California
# 9977  Standard Class  Home Office  United States   Los Angeles  California
# 9978  Standard Class  Home Office  United States   Los Angeles  California
# 9979  Standard Class  Home Office  United States   Los Angeles  California
# 9980    Second Class     Consumer  United States     Lafayette   Louisiana
# 9981     First Class     Consumer  United States     Fairfield        Ohio
# 9982  Standard Class     Consumer  United States  Grand Rapids    Michigan
# 9983  Standard Class     Consumer  United States  Grand Rapids    Michigan
# 9984  Standard Class     Consumer  United States    Long Beach    New York
# ...

# %%
df.sample()
# Out:
#      Ship Mode   Segment        Country   City    State  Postal Code Region  \
# 9566  Same Day  Consumer  United States  Tampa  Florida        33614  South
#
#              Category Sub-Category   Sales  Quantity  Discount  Profit
# 9566  Office Supplies      Binders  12.645         5       0.7 -10.116

# %%
df.sample(20)
# Out:
#            Ship Mode      Segment        Country           City  \
# 6820  Standard Class    Corporate  United States         Peoria
# 1470  Standard Class    Corporate  United States        Detroit
# 226   Standard Class    Corporate  United States        Detroit
# 4498  Standard Class    Corporate  United States  San Francisco
# 463   Standard Class  Home Office  United States        Phoenix
# 35       First Class    Corporate  United States     Richardson
# 9377  Standard Class    Corporate  United States     Eau Claire
# 1508        Same Day  Home Office  United States          Omaha
# 3733  Standard Class    Corporate  United States        Clinton
# 2451    Second Class     Consumer  United States  New York City
# 1485  Standard Class     Consumer  United States  New York City
# 81    Standard Class     Consumer  United States  San Francisco
# 4481  Standard Class     Consumer  United States    Los Angeles
# 1554  Standard Class    Corporate  United States       Bellevue
# ...

# %%
df.shape
# Out:
# (9994, 13)

# %%
len(df)
# Out:
# 9994

# %%
df.index
# Out:
# RangeIndex(start=0, stop=9994, step=1)

# %%
df.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=9994, step=1),
#  Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#         'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#         'Profit'],
#        dtype='object')]

# %%
df.size
# Out:
# 129922

# %%
df.ndim
# Out:
# 2

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.857901     3.789574     0.156203    28.656599
# std    32063.693350    623.245124     2.225110     0.206452   234.260115
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
sorted_df = df.sort_values(by="Sales")

# %%
sorted_df
# Out:
#            Ship Mode      Segment        Country           City         State  \
# 4101  Standard Class     Consumer  United States        Houston         Texas
# 9292        Same Day    Corporate  United States           Waco         Texas
# 8658  Standard Class    Corporate  United States        Chicago      Illinois
# 4711        Same Day     Consumer  United States   Philadelphia  Pennsylvania
# 2106        Same Day    Corporate  United States       Mesquite         Texas
# ...              ...          ...            ...            ...           ...
# 4190  Standard Class     Consumer  United States         Newark      Delaware
# 2623     First Class  Home Office  United States  New York City      New York
# 8153     First Class     Consumer  United States        Seattle    Washington
# 6826  Standard Class    Corporate  United States      Lafayette       Indiana
# 2697  Standard Class  Home Office  United States   Jacksonville       Florida
#
# ...

# %%
sorted_df = df.sort_values(by="Sales",ascending=False)
sorted_df
# Out:
#            Ship Mode      Segment        Country           City         State  \
# 2697  Standard Class  Home Office  United States   Jacksonville       Florida
# 6826  Standard Class    Corporate  United States      Lafayette       Indiana
# 8153     First Class     Consumer  United States        Seattle    Washington
# 2623     First Class  Home Office  United States  New York City      New York
# 4190  Standard Class     Consumer  United States         Newark      Delaware
# ...              ...          ...            ...            ...           ...
# 2106        Same Day    Corporate  United States       Mesquite         Texas
# 4711        Same Day     Consumer  United States   Philadelphia  Pennsylvania
# 8658  Standard Class    Corporate  United States        Chicago      Illinois
# 9292        Same Day    Corporate  United States           Waco         Texas
# 4101  Standard Class     Consumer  United States        Houston         Texas
#
# ...
